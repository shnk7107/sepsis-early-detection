# %%
# !python sepsis_day4_permimp.py
# Out:
# fitting 1_none_baseline ...
#   summed permutation importance (AUPRC drop) by group:
#     SOFA_lab_core            +0.0027
#     SOFA_other(MAP+resp)     +0.0202
#     non_SOFA                 +0.0568
# fitting 8_SMOTETomek_aggressive ...
#   summed permutation importance (AUPRC drop) by group:
#     SOFA_lab_core            +0.0067
#     SOFA_other(MAP+resp)     +0.0299
#     non_SOFA                 +0.0707
#
# === correlation screen: lab-core SOFA indicators vs all other indicators ===
#   Creatinine_n               max |corr| with another indicator = 0.94  (BUN_measured)
#   Bilirubin_total_n          max |corr| with another indicator = 0.94  (Alkalinephos_measured)
#   Platelets_n                max |corr| with another indicator = 0.91  (WBC_measured)
#   Creatinine_measured        max |corr| with another indicator = 0.97  (BUN_measured)
#   Bilirubin_total_measured   max |corr| with another indicator = 0.95  (Alkalinephos_measured)
# ...

# %%
# !python sepsis_day4_perfold.py
# Out:
# [full     1_none          ] 5 folds saved  (68s)
# [full     2_class_weight  ] 5 folds saved  (47s)
# [full     3_RandomUnder   ] 5 folds saved  (9s)
# [full     4_RandomOver    ] 5 folds saved  (75s)
# [full     5_SMOTENC       ] 5 folds saved  (194s)
# [full     6_BorderlineSMOTE] 5 folds saved  (122s)
# [full     7_ADASYN        ] 5 folds saved  (113s)
# [full     8_SMOTETomek    ] 5 folds saved  (157s)
# [lab_core 1_none          ] 5 folds saved  (64s)
# [lab_core 2_class_weight  ] 5 folds saved  (44s)
# [lab_core 3_RandomUnder   ] 5 folds saved  (10s)
# [lab_core 4_RandomOver    ] 5 folds saved  (70s)
# [lab_core 5_SMOTENC       ] 5 folds saved  (181s)
# [lab_core 6_BorderlineSMOTE] 5 folds saved  (118s)
# [lab_core 7_ADASYN        ] 5 folds saved  (108s)
# [lab_core 8_SMOTETomek    ] 5 folds saved  (148s)
# [all_7    1_none          ] 5 folds saved  (57s)
# [all_7    2_class_weight  ] 5 folds saved  (41s)
# [all_7    3_RandomUnder   ] 5 folds saved  (8s)
# ...

# %%
# !python sepsis_day4_pairedtest.py
# Out:
# === paired dAUPRC test · lab_core (headline) ===
#         condition  mean_d   sd_d  ttest_p  wilcoxon_p  all_same_sign
#            1_none  0.0007 0.0076   0.8504      1.0000          False
#    2_class_weight -0.0059 0.0063   0.1057      0.1250          False
#     3_RandomUnder  0.0009 0.0117   0.8760      1.0000          False
#      4_RandomOver  0.0080 0.0052   0.0267      0.0625           True
#         5_SMOTENC  0.0002 0.0024   0.8484      1.0000          False
# 6_BorderlineSMOTE -0.0046 0.0052   0.1179      0.1250          False
#          7_ADASYN  0.0011 0.0084   0.7751      1.0000          False
#      8_SMOTETomek -0.0030 0.0070   0.3995      0.4375          False
#   conditions with t-test p<0.05: 1/8  |  mean dAUPRC across gradient: -0.0003  |  sign-consistent: 1/8
#
# === paired dAUPRC test · all_7 (companion) ===
#         condition  mean_d   sd_d  ttest_p  wilcoxon_p  all_same_sign
#            1_none  0.0105 0.0096   0.0714      0.1250          False
# ...
