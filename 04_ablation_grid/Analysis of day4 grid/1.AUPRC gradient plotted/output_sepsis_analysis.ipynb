# %%
# !python sepsis_day4_analysis.py
# Out:
# === dAUPRC = AUPRC(full) - AUPRC(ablated) ===  (TEST set)
#
# --- ablation: lab_core (headline)
#         condition  full_test  ablated_test  dAUPRC_test  pooled_sd  within_noise
#            1_none      0.164         0.162        0.002      0.023          True
#    2_class_weight      0.156         0.165       -0.009      0.017          True
#     3_RandomUnder      0.149         0.154       -0.005      0.014          True
#      4_RandomOver      0.170         0.162        0.007      0.018          True
#         5_SMOTENC      0.154         0.147        0.007      0.011          True
# 6_BorderlineSMOTE      0.168         0.169       -0.001      0.014          True
#          7_ADASYN      0.164         0.161        0.003      0.014          True
#      8_SMOTETomek      0.168         0.168        0.001      0.017          True
#     8/8 conditions have |dAUPRC| < pooled fold-sd (indistinguishable from 0 on this screen)
#     max |dAUPRC| = 0.009  | mean dAUPRC = +0.001
#
# ...
