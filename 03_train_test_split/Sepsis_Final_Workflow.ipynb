# %%
# !pip install -q imbalanced-learn

# %%
# !python sepsis_day3_skeleton.py
# Out:
# features 243  |  numeric 172  categorical 71
#
# === LEAKAGE ASSERTIONS ===
#   [PASS] no_pid_overlap
#   [PASS] prevalence_preserved
#   [PASS] abmix_preserved
#   [PASS] nan_before_impute_present
#   [PASS] zero_nan_into_smote
#   [PASS] imputer_uses_train_fold_only
#   [PASS] test_size_unchanged
#   [PASS] test_not_resampled
#   [PASS] smotenc_categoricals_discrete
#
# === METRICS (skeleton, untuned) ===
# CV AUPRC  0.153 ± 0.009
# CV AUROC  0.721 ± 0.010
# TEST AUPRC 0.154   (baseline = prevalence 0.071)
# TEST AUROC 0.716
#
# === WORKED EXAMPLE ===
# pid p007810: in_train=False  in_test=True   (must be in exactly one)
#   Creatinine_mean: raw=nan  -> imputed(train median)=0.900  -> scaled=-0.190
#
# STATUS: PASS — trusted skeleton
# saved: day3_test_pids.json
