# %%
# !python sepsis_day5_panel.py
# Out:
# arm lab_panel: 61 features (42 num, 19 cat)
#   [1_none          ] test_auprc=0.134  (55.0s)
#   [2_class_weight  ] test_auprc=0.133  (44.2s)
#   [3_RandomUnder   ] test_auprc=0.139  (8.3s)
#   [4_RandomOver    ] test_auprc=0.145  (63.4s)
#   [5_SMOTENC       ] test_auprc=0.133  (151.5s)
#   [6_BorderlineSMOTE] test_auprc=0.142  (113.0s)
#   [7_ADASYN        ] test_auprc=0.149  (105.1s)
#   [8_SMOTETomek    ] test_auprc=0.148  (128.1s)
#
# arm lab_indicators_only: 191 features (172 num, 19 cat)
#   [1_none          ] test_auprc=0.161  (82.5s)
#   [2_class_weight  ] test_auprc=0.154  (56.9s)
#   [3_RandomUnder   ] test_auprc=0.148  (11.8s)
#   [4_RandomOver    ] test_auprc=0.159  (89.6s)
#   [5_SMOTENC       ] test_auprc=0.144  (196.4s)
#   [6_BorderlineSMOTE] test_auprc=0.164  (152.8s)
#   [7_ADASYN        ] test_auprc=0.161  (144.2s)
#   [8_SMOTETomek    ] test_auprc=0.158  (187.9s)
#
# DAY 5 ARMS COMPLETE

# %%
# !python sepsis_day5_analysis.py
# Out:
# === dAUPRC = AUPRC(full) - AUPRC(ablated), TEST set ===
#                    lab_core  lab_panel  lab_indicators_only   all_7
# 1_none               0.0019     0.0299               0.0030  0.0187
# 2_class_weight      -0.0092     0.0229               0.0025  0.0099
# 3_RandomUnder       -0.0045     0.0108               0.0017  0.0151
# 4_RandomOver         0.0074     0.0252               0.0105  0.0277
# 5_SMOTENC            0.0073     0.0211               0.0102  0.0257
# 6_BorderlineSMOTE   -0.0013     0.0258               0.0039  0.0190
# 7_ADASYN             0.0032     0.0153               0.0036  0.0150
# 8_SMOTETomek         0.0009     0.0201               0.0108  0.0183
#
# === lab-signal decomposition (test dAUPRC) ===
#                    total_lab(full-panel)  circularity(full-indicators)  physiology(panel-indicators)
# 1_none                            0.0299                        0.0030                       -0.0269
# ...
