# %%
# !python sepsis_day6_repeated.py     # rerun until "DAY 6 COMPLETE"
# Out:
# arm full: 243 features
#   [1_none          ] 25 splits saved  (306s)
#   [2_class_weight  ] 25 splits saved  (216s)
#   [3_RandomUnder   ] 25 splits saved  (48s)
#   [4_RandomOver    ] 25 splits saved  (341s)
#   [5_SMOTENC       ] 25 splits saved  (900s)
#   [6_BorderlineSMOTE] 25 splits saved  (557s)
#   [7_ADASYN        ] 25 splits saved  (509s)
#   [8_SMOTETomek    ] 25 splits saved  (719s)
#
# arm lab_panel: 61 features
#   [1_none          ] 25 splits saved  (214s)
#   [2_class_weight  ] 25 splits saved  (166s)
#   [3_RandomUnder   ] 25 splits saved  (35s)
#   [4_RandomOver    ] 25 splits saved  (244s)
#   [5_SMOTENC       ] 25 splits saved  (585s)
#   [6_BorderlineSMOTE] 25 splits saved  (436s)
#   [7_ADASYN        ] 25 splits saved  (406s)
#   [8_SMOTETomek    ] 25 splits saved  (496s)
#
# arm lab_indicators_only: 191 features
#   [1_none          ] 25 splits saved  (314s)
#   [2_class_weight  ] 25 splits saved  (218s)
#   [3_RandomUnder   ] 25 splits saved  (46s)
# ...

# %%
# !python sepsis_day6_analysis.py
# Out:
# === full vs lab_indicators_only · LAB CIRCULARITY (ordering beyond value) ===
#         condition  mean_d  ci95_halfwidth  p_corrected  p_naive  sig_corrected
#            1_none  0.0050          0.0104       0.3302   0.0132          False
#    2_class_weight  0.0065          0.0106       0.2181   0.0023          False
#     3_RandomUnder  0.0056          0.0110       0.3038   0.0093          False
#      4_RandomOver  0.0068          0.0096       0.1587   0.0006          False
#         5_SMOTENC  0.0029          0.0078       0.4446   0.0471          False
# 6_BorderlineSMOTE  0.0090          0.0103       0.0825   0.0001          False
#          7_ADASYN  0.0102          0.0120       0.0939   0.0001          False
#      8_SMOTETomek  0.0130          0.0119       0.0326   0.0000           True
#   significant (corrected) in 1/8  |  naive would claim 8/8  |  mean dAUPRC +0.0074
#
# === full vs all_7 · VITAL-PROXY reliance ===
# ...
