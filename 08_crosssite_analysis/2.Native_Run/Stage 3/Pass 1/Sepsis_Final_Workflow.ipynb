# %%
# !python psA_matched_run.py
# Out:
# skip ('A->B', 'RF', '1_none', 'full')
# skip ('A->B', 'RF', '1_none', 'lab_indicators_only')
# skip ('A->B', 'RF', '5_SMOTENC', 'full')
# [X A->B RF        5_SMOTENC lab_indicators_only ] AUPRC=0.106 (24s)
# [X A->B xgboost   1_none    full                ] AUPRC=0.091 (7s)
# [X A->B xgboost   1_none    lab_indicators_only ] AUPRC=0.098 (5s)
# [X A->B xgboost   5_SMOTENC full                ] AUPRC=0.082 (23s)
# [X A->B xgboost   5_SMOTENC lab_indicators_only ] AUPRC=0.090 (16s)
# [X A->B lightgbm  1_none    full                ] AUPRC=0.091 (5s)
# [X A->B lightgbm  1_none    lab_indicators_only ] AUPRC=0.091 (4s)
# [X A->B lightgbm  5_SMOTENC full                ] AUPRC=0.084 (19s)
# [X A->B lightgbm  5_SMOTENC lab_indicators_only ] AUPRC=0.088 (12s)
# [X B->A RF        1_none    full                ] AUPRC=0.158 (9s)
# [X B->A RF        1_none    lab_indicators_only ] AUPRC=0.153 (10s)
# [X B->A RF        5_SMOTENC full                ] AUPRC=0.116 (28s)
# ...

# %%
# !python psA_prevalence_aware_analysis.py
# Out:
# ...
# PS-A ANALYSIS  [psA_native]   target-site prevalence (AUPRC is prevalence-dependent)
# ...
#   A->B: target = site B   n= 7488   prevalence= 5.56%
#   B->A: target = site A   n= 7821   prevalence= 9.09%
#
# ...
# Q1  ORDERING RELIANCE, cross-site.   delta = AUPRC(full) - AUPRC(ordering_dropped)
#     Both arms scored on the SAME target patients -> prevalence cancels. Paired bootstrap.
#     <0 with CI excluding 0  =>  dropping ordering IMPROVES transfer (a shortcut).
# ...
#      cond direction    model   delta      lo      hi   sig
#    1_none      A->B       RF -0.0005 -0.0108 +0.0085 False
#    1_none      A->B  xgboost -0.0072 -0.0167 +0.0005 False
#    1_none      A->B lightgbm -0.0002 -0.0089 +0.0110 False
#    1_none      B->A       RF +0.0050 -0.0014 +0.0115 False
#    1_none      B->A  xgboost +0.0049 -0.0026 +0.0141 False
#    1_none      B->A lightgbm -0.0036 -0.0113 +0.0049 False
# 5_SMOTENC      A->B       RF +0.0007 -0.0098 +0.0116 False
# ...
