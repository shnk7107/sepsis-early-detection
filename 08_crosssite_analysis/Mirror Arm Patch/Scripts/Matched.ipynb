# %%
#!python psA_matched_run_native.py

# !pip -q install imbalanced-learn xgboost lightgbm pyarrow
# %run psA_matched_run.py
# Out:
# Mounted at /content/drive
# ==============================================================================
# PREFLIGHT
# ==============================================================================
#   DATA_DIR -> /content
#   OUT_DIR  -> /content/psa_out
#   input OK: features.parquet
#   input OK: feature_tags.csv
#   features: n=15778  prevalence=0.0714  sites={'A': np.int64(9954), 'B': np.int64(5824)}
#
#   arm widths (expect 52|0/52, 130|130/0, 61|42/19):
#     full                   total=243 | num=172 cat= 71
#     lab_indicators_only    total=191 | num=172 cat= 19
#     lab_values_dropped     total=113 | num= 42 cat= 71
#     ordering_only          total= 52 | num=  0 cat= 52
#     values_only            total=130 | num=130 cat=  0
#     lab_panel              total= 61 | num= 42 cat= 19
#   found prior psA_crosssite_preds.csv
#     at   /content/psA_crosssite_preds.csv
#     -> copied into OUT_DIR
#   found prior psA_withinsrc_perfold.csv
#     at   /content/psA_withinsrc_perfold.csv
#     -> copied into OUT_DIR
#
#   existing outputs:
#     psA_crosssite_preds.csv             189,336 rows | arms=['full', 'lab_indicators_only'] | duplicate rows=0
#     psA_withinsrc_perfold.csv               600 rows | arms=['full', 'lab_indicators_only'] | duplicate rows=0
#
#   PREFLIGHT PASSED -> expect a wall of 'skip (...)' lines next.
# ==============================================================================
#
# skip ('A->B', 'RF', '1_none', 'full')
# skip ('A->B', 'RF', '1_none', 'lab_indicators_only')
# [X A->B RF        1_none    lab_values_dropped  ] AUPRC=0.144 (6s)
# [X A->B RF        1_none    ordering_only       ] AUPRC=0.102 (2s)
# [X A->B RF        1_none    values_only         ] AUPRC=0.105 (9s)
# [X A->B RF        1_none    lab_panel           ] AUPRC=0.120 (7s)
# skip ('A->B', 'RF', '5_SMOTENC', 'full')
# skip ('A->B', 'RF', '5_SMOTENC', 'lab_indicators_only')
# [X A->B RF        5_SMOTENC lab_values_dropped  ] AUPRC=0.103 (30s)
# [X A->B RF        5_SMOTENC lab_panel           ] AUPRC=0.084 (23s)
# skip ('A->B', 'xgboost', '1_none', 'full')
# skip ('A->B', 'xgboost', '1_none', 'lab_indicators_only')
# [X A->B xgboost   1_none    lab_values_dropped  ] AUPRC=0.110 (3s)
# [X A->B xgboost   1_none    ordering_only       ] AUPRC=0.090 (1s)
# [X A->B xgboost   1_none    values_only         ] AUPRC=0.076 (3s)
# [X A->B xgboost   1_none    lab_panel           ] AUPRC=0.103 (2s)
# skip ('A->B', 'xgboost', '5_SMOTENC', 'full')
# skip ('A->B', 'xgboost', '5_SMOTENC', 'lab_indicators_only')
# [X A->B xgboost   5_SMOTENC lab_values_dropped  ] AUPRC=0.096 (17s)
# [X A->B xgboost   5_SMOTENC lab_panel           ] AUPRC=0.100 (7s)
# skip ('A->B', 'lightgbm', '1_none', 'full')
# skip ('A->B', 'lightgbm', '1_none', 'lab_indicators_only')
# [X A->B lightgbm  1_none    lab_values_dropped  ] AUPRC=0.099 (2s)
# [X A->B lightgbm  1_none    ordering_only       ] AUPRC=0.084 (1s)
# [X A->B lightgbm  1_none    values_only         ] AUPRC=0.069 (3s)
# [X A->B lightgbm  1_none    lab_panel           ] AUPRC=0.104 (3s)
# skip ('A->B', 'lightgbm', '5_SMOTENC', 'full')
# skip ('A->B', 'lightgbm', '5_SMOTENC', 'lab_indicators_only')
# [X A->B lightgbm  5_SMOTENC lab_values_dropped  ] AUPRC=0.095 (15s)
# [X A->B lightgbm  5_SMOTENC lab_panel           ] AUPRC=0.092 (6s)
# skip ('B->A', 'RF', '1_none', 'full')
# skip ('B->A', 'RF', '1_none', 'lab_indicators_only')
# [X B->A RF        1_none    lab_values_dropped  ] AUPRC=0.129 (4s)
# [X B->A RF        1_none    ordering_only       ] AUPRC=0.093 (1s)
# [X B->A RF        1_none    values_only         ] AUPRC=0.109 (5s)
# [X B->A RF        1_none    lab_panel           ] AUPRC=0.116 (4s)
# skip ('B->A', 'RF', '5_SMOTENC', 'full')
# skip ('B->A', 'RF', '5_SMOTENC', 'lab_indicators_only')
# [X B->A RF        5_SMOTENC lab_values_dropped  ] AUPRC=0.089 (16s)
# [X B->A RF        5_SMOTENC lab_panel           ] AUPRC=0.101 (13s)
# skip ('B->A', 'xgboost', '1_none', 'full')
# skip ('B->A', 'xgboost', '1_none', 'lab_indicators_only')
# [X B->A xgboost   1_none    lab_values_dropped  ] AUPRC=0.115 (2s)
# [X B->A xgboost   1_none    ordering_only       ] AUPRC=0.085 (1s)
# [X B->A xgboost   1_none    values_only         ] AUPRC=0.096 (2s)
# [X B->A xgboost   1_none    lab_panel           ] AUPRC=0.113 (2s)
# skip ('B->A', 'xgboost', '5_SMOTENC', 'full')
# skip ('B->A', 'xgboost', '5_SMOTENC', 'lab_indicators_only')
# [X B->A xgboost   5_SMOTENC lab_values_dropped  ] AUPRC=0.101 (11s)
# [X B->A xgboost   5_SMOTENC lab_panel           ] AUPRC=0.105 (6s)
# skip ('B->A', 'lightgbm', '1_none', 'full')
# skip ('B->A', 'lightgbm', '1_none', 'lab_indicators_only')
# [X B->A lightgbm  1_none    lab_values_dropped  ] AUPRC=0.113 (3s)
# [X B->A lightgbm  1_none    ordering_only       ] AUPRC=0.084 (1s)
# [X B->A lightgbm  1_none    values_only         ] AUPRC=0.099 (2s)
# [X B->A lightgbm  1_none    lab_panel           ] AUPRC=0.115 (2s)
# skip ('B->A', 'lightgbm', '5_SMOTENC', 'full')
# skip ('B->A', 'lightgbm', '5_SMOTENC', 'lab_indicators_only')
# [X B->A lightgbm  5_SMOTENC lab_values_dropped  ] AUPRC=0.098 (11s)
# [X B->A lightgbm  5_SMOTENC lab_panel           ] AUPRC=0.104 (4s)
# TIER 1 CROSS-SITE DONE
# skip ('A', 'RF', '1_none', 'full')
# skip ('A', 'RF', '1_none', 'lab_indicators_only')
# [W A RF        1_none    lab_values_dropped  ] AUPRC=0.176 (131s)
# [W A RF        1_none    ordering_only       ] AUPRC=0.134 (33s)
# [W A RF        1_none    values_only         ] AUPRC=0.132 (132s)
# [W A RF        1_none    lab_panel           ] AUPRC=0.155 (147s)
# skip ('A', 'RF', '5_SMOTENC', 'full')
# skip ('A', 'RF', '5_SMOTENC', 'lab_indicators_only')
# [W A RF        5_SMOTENC lab_values_dropped  ] AUPRC=0.155 (581s)
# [W A RF        5_SMOTENC lab_panel           ] AUPRC=0.145 (437s)
# skip ('A', 'xgboost', '1_none', 'full')
# skip ('A', 'xgboost', '1_none', 'lab_indicators_only')
# [W A xgboost   1_none    lab_values_dropped  ] AUPRC=0.180 (68s)
# [W A xgboost   1_none    ordering_only       ] AUPRC=0.144 (15s)
# [W A xgboost   1_none    values_only         ] AUPRC=0.125 (74s)
# [W A xgboost   1_none    lab_panel           ] AUPRC=0.161 (55s)
# skip ('A', 'xgboost', '5_SMOTENC', 'full')
# skip ('A', 'xgboost', '5_SMOTENC', 'lab_indicators_only')
# [W A xgboost   5_SMOTENC lab_values_dropped  ] AUPRC=0.169 (338s)
# [W A xgboost   5_SMOTENC lab_panel           ] AUPRC=0.153 (154s)
# skip ('A', 'lightgbm', '1_none', 'full')
# skip ('A', 'lightgbm', '1_none', 'lab_indicators_only')
# [W A lightgbm  1_none    lab_values_dropped  ] AUPRC=0.178 (48s)
# [W A lightgbm  1_none    ordering_only       ] AUPRC=0.136 (15s)
# [W A lightgbm  1_none    values_only         ] AUPRC=0.113 (57s)
# [W A lightgbm  1_none    lab_panel           ] AUPRC=0.156 (42s)
# skip ('A', 'lightgbm', '5_SMOTENC', 'full')
# skip ('A', 'lightgbm', '5_SMOTENC', 'lab_indicators_only')
# [W A lightgbm  5_SMOTENC lab_values_dropped  ] AUPRC=0.166 (308s)
# [W A lightgbm  5_SMOTENC lab_panel           ] AUPRC=0.151 (130s)
# skip ('B', 'RF', '1_none', 'full')
# skip ('B', 'RF', '1_none', 'lab_indicators_only')
# [W B RF        1_none    lab_values_dropped  ] AUPRC=0.198 (81s)
# [W B RF        1_none    ordering_only       ] AUPRC=0.104 (20s)
# [W B RF        1_none    values_only         ] AUPRC=0.127 (73s)
# [W B RF        1_none    lab_panel           ] AUPRC=0.180 (90s)
# skip ('B', 'RF', '5_SMOTENC', 'full')
# skip ('B', 'RF', '5_SMOTENC', 'lab_indicators_only')
# [W B RF        5_SMOTENC lab_values_dropped  ] AUPRC=0.137 (327s)
# [W B RF        5_SMOTENC lab_panel           ] AUPRC=0.146 (242s)
# skip ('B', 'xgboost', '1_none', 'full')
# skip ('B', 'xgboost', '1_none', 'lab_indicators_only')
# [W B xgboost   1_none    lab_values_dropped  ] AUPRC=0.183 (47s)
# [W B xgboost   1_none    ordering_only       ] AUPRC=0.105 (10s)
# [W B xgboost   1_none    values_only         ] AUPRC=0.102 (49s)
# [W B xgboost   1_none    lab_panel           ] AUPRC=0.168 (41s)
# skip ('B', 'xgboost', '5_SMOTENC', 'full')
# skip ('B', 'xgboost', '5_SMOTENC', 'lab_indicators_only')
# [W B xgboost   5_SMOTENC lab_values_dropped  ] AUPRC=0.166 (222s)
# [W B xgboost   5_SMOTENC lab_panel           ] AUPRC=0.155 (115s)
# skip ('B', 'lightgbm', '1_none', 'full')
# skip ('B', 'lightgbm', '1_none', 'lab_indicators_only')
# [W B lightgbm  1_none    lab_values_dropped  ] AUPRC=0.185 (38s)
# [W B lightgbm  1_none    ordering_only       ] AUPRC=0.102 (12s)
# [W B lightgbm  1_none    values_only         ] AUPRC=0.087 (36s)
# [W B lightgbm  1_none    lab_panel           ] AUPRC=0.169 (37s)
# skip ('B', 'lightgbm', '5_SMOTENC', 'full')
# skip ('B', 'lightgbm', '5_SMOTENC', 'lab_indicators_only')
# [W B lightgbm  5_SMOTENC lab_values_dropped  ] AUPRC=0.165 (200s)
# [W B lightgbm  5_SMOTENC lab_panel           ] AUPRC=0.155 (97s)
# TIER 2 WITHIN-SOURCE DONE
