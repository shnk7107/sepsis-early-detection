# %%
# !pip install -q xgboost lightgbm

# %%
# !python sepsis_day7_models.py      # rerun until "DAY 7 COMPLETE"
# Out:
# [xgboost] arm full: 243 features
#   [1_none          ] saved  (150s)
#   [2_class_weight  ] saved  (180s)
#   [3_RandomUnder   ] saved  (69s)
#   [4_RandomOver    ] saved  (205s)
#   [5_SMOTENC       ] saved  (524s)
#   [6_BorderlineSMOTE] saved  (304s)
#   [7_ADASYN        ] saved  (296s)
#   [8_SMOTETomek    ] saved  (503s)
#
# [xgboost] arm lab_panel: 61 features
#   [1_none          ] saved  (59s)
#   [2_class_weight  ] saved  (67s)
#   [3_RandomUnder   ] saved  (31s)
#   [4_RandomOver    ] saved  (77s)
#   [5_SMOTENC       ] saved  (166s)
#   [6_BorderlineSMOTE] saved  (106s)
#   [7_ADASYN        ] saved  (105s)
#   [8_SMOTETomek    ] saved  (189s)
#
# [xgboost] arm lab_indicators_only: 191 features
#   [1_none          ] saved  (138s)
#   [2_class_weight  ] saved  (167s)
#   [3_RandomUnder   ] saved  (66s)
#   [4_RandomOver    ] saved  (188s)
#   [5_SMOTENC       ] saved  (282s)
#   [6_BorderlineSMOTE] saved  (205s)
#   [7_ADASYN        ] saved  (202s)
# ...

# %%
# !python sepsis_day7_analysis.py
# Out:
# === corrected-significant conditions per model (out of 8) ===
# arm                       RF   xgboost   lightgbm
# lab_indicators_only        1/8       0/8       0/8
# all_7                      2/8       4/8       4/8
# lab_panel                  7/8       7/8       7/8
#
# === mean dAUPRC across the gradient, per model ===
# arm                         RF   xgboost   lightgbm
# lab_indicators_only      +0.0074   +0.0069   +0.0066
# all_7                    +0.0105   +0.0124   +0.0156
# lab_panel                +0.0206   +0.0187   +0.0224
#
# === VERDICT: lab-circularity amplification (full vs lab_indicators_only) ===
#   RF       : 1/8 corrected-significant, mean dAUPRC +0.0074  -> NULL holds
#   xgboost  : 0/8 corrected-significant, mean dAUPRC +0.0069  -> NULL holds
#   lightgbm : 0/8 corrected-significant, mean dAUPRC +0.0066  -> NULL holds
#
# wrote: day7_crossmodel_significance.csv, day7_crossmodel_gradient.png
